# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import numpy.ma as ma
from collections import Counter
import random

threashold = 1e-05
word_counts = Counter(int_words)
# Counter({0: 1061396, 1: 593677, 2: 416629, 3: 411764, 4: 372201, 5: 325873, ..., 63639: 6, 63640: 6})
total_count = len(int_words)
# 16680599
wordfreq = {word: count/total_count for word, count in word_counts.items()}
# {0: 0.06363056866243233, 1: 0.035590868169662254,..., 63639: 3.5969931295632727e-07, 63640: 3.5969931295632727e-07}
drop_word = {word: 1 - np.sqrt(threashold/wordfreq[word]) for word in word_counts}
# {0: 0.98746376577740469, 1: 0.98323781193133519, ... , 63639: -4.2726652020902423, 63640: -4.2726652020902423}

# %%
train_words = [word for word in int_words if drop_word[word] < random.random()]
train_words[:10]
# Out:
# [5234, 3081, 127, 741, 10634, 27621, 15188, 60650, 150, 3582]

# %%
train_words = [word for word in int_words if drop_word[word] < random.random()]
train_words[:10]
# Out:
# [5234, 11, 10634, 27621, 15188, 60650, 194, 10745, 2733, 708]

# %%
train_words = [word for word in int_words if drop_word[word] < random.random()]
train_words[:10]
# Out:
# [5234, 3081, 155, 10634, 27621, 15188, 60650, 854, 3582, 10745]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    end = idx + R
    target_words = set(words[start:idx] + words[idx+1:end])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
    
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros((n_vocab))) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6469 0.3850 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5992 0.3487 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4712 0.3386 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5795 0.3380 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5030 0.3362 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5401 0.3347 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5495 0.3358 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5800 0.3332 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4819 0.3353 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4285 0.3372 sec/batch
# Nearest to so: rebus, eider, hostilities, manny, morrigan, chimaera, adversarial, globalisation,
# Nearest to many: resonate, fusible, goggles, ventspils, its, gadget, puzzling, outbreaks,
# Nearest to with: cinerama, maker, rewrites, geodesy, supplemental, gruppe, foundational, metering,
# Nearest to have: supersymmetry, surrounded, improv, chernobyl, racetrack, interferon, future, certainly,
# Nearest to world: hurdles, hierarchal, helga, seram, philistine, structural, concludes, corbucci,
# Nearest to first: neoclassical, beagles, griswold, gunshot, tartarus, edd, greatest, russa,
# Nearest to from: raiders, methionine, bissette, outsource, raffles, cutting, spoofing, dutton,
# Nearest to all: parcels, poses, cocos, foliage, ayres, holloway, zahn, ed,
# Nearest to channel: clubs, conjugate, clonaid, digweed, spite, manica, cycles, ulster,
# Nearest to centre: haer, superiore, else, cementing, letters, timespan, intelligible, showcase,
# Nearest to woman: arius, interregnum, freeze, kwh, recover, pata, drinks, evans,
# Nearest to experience: hole, homyel, studied, cadence, paid, steroids, surviving, produce,
# Nearest to resources: lovell, stanford, lpga, sennett, cz, layperson, onlookers, clues,
# Nearest to http: contained, reginald, nepomuk, dosing, creamy, luxembourgian, anhalt, taliban,
# Nearest to bbc: and, spying, vili, eta, subtree, observance, partying, immediate,
# Nearest to creation: regrowth, omitting, discount, chipsets, freespire, standardise, excels, assign,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4787 0.4072 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3945 0.3742 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3551 0.4051 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2316 0.3727 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1694 0.3524 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1600 0.3532 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0926 0.3532 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0832 0.3566 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0128 0.3510 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9915 0.3552 sec/batch
# Nearest to so: before, hostilities, scene, globalisation, eider, morrigan, adversarial, improve,
# Nearest to many: its, goggles, fusible, resonate, ventspils, plus, instructed, estimated,
# Nearest to with: maker, foundational, general, rewrites, supplemental, includes, disk, cinerama,
# Nearest to have: surrounded, future, certainly, racetrack, supersymmetry, point, distinctively, more,
# Nearest to world: answer, shows, went, hurdles, structural, hundreds, sometimes, buried,
# Nearest to first: neoclassical, greatest, beagles, home, griswold, edd, innumerable, proposal,
# Nearest to from: raiders, because, bissette, cutting, percent, methionine, strong, outsource,
# Nearest to all: foliage, ed, poses, parcels, emerging, earthquakes, bulletins, diane,
# Nearest to channel: clubs, conjugate, spite, clonaid, digweed, warm, cycles, ulster,
# Nearest to centre: else, letters, haer, intelligible, unimportant, appeasement, activating, konya,
# Nearest to woman: freeze, interregnum, arius, recover, evans, less, polish, sean,
# Nearest to experience: hole, paid, studied, units, produce, believing, homyel, surviving,
# Nearest to resources: stanford, lovell, examples, secured, lpga, goes, clues, layperson,
# Nearest to http: contained, luxembourgian, putin, dosing, reginald, nepomuk, artist, authoritarianism,
# Nearest to bbc: and, functionality, spying, immediate, referral, how, observance, eta,
# Nearest to creation: individuals, omitting, civil, regrowth, assign, labeling, among, discount,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9321 0.3882 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9330 0.3525 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9023 0.3551 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8790 0.3550 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8093 0.3964 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8346 0.5397 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7945 0.3900 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7905 0.3840 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7994 0.3852 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7905 0.3808 sec/batch
# Nearest to so: hostilities, before, exceedingly, eider, globalisation, scene, morrigan, improve,
# Nearest to many: resonate, goggles, its, fusible, instructed, ventspils, coefficient, linking,
# Nearest to with: maker, supplemental, cinerama, geodesy, foundational, rewrites, sketch, distances,
# Nearest to have: surrounded, supersymmetry, racetrack, certainly, chernobyl, future, surprisingly, ascension,
# Nearest to world: hurdles, buried, answer, hierarchal, structural, transition, went, helga,
# Nearest to first: neoclassical, greatest, griswold, beagles, innumerable, home, edd, nash,
# Nearest to from: raiders, because, cutting, clones, methionine, bissette, outsource, initial,
# Nearest to all: poses, foliage, ed, parcels, emerging, consolidated, finely, judiciary,
# Nearest to channel: clubs, conjugate, spite, clonaid, cycles, digweed, ulster, filename,
# Nearest to centre: else, intelligible, letters, showcase, unimportant, haer, appeasement, activating,
# Nearest to woman: interregnum, arius, evans, freeze, recover, drinks, polish, exclusive,
# Nearest to experience: hole, cadence, paid, homyel, adopting, units, believing, studied,
# Nearest to resources: stanford, lovell, secured, layperson, cz, lpga, clues, examples,
# Nearest to http: contained, luxembourgian, dosing, putin, taliban, reginald, holger, artist,
# Nearest to bbc: and, functionality, spying, immediate, observance, eta, referral, how,
# Nearest to creation: discount, civil, individuals, assign, omitting, regrowth, labeling, standardise,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7943 0.3871 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7693 0.4174 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7266 0.3949 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6988 0.4105 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7536 0.4073 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7236 0.4110 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7001 0.4071 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7135 0.4139 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7082 0.3973 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6681 0.3943 sec/batch
# Nearest to so: hostilities, exceedingly, globalisation, makin, tinted, eider, before, morrigan,
# Nearest to many: goggles, resonate, fusible, its, coefficient, ventspils, instructed, gadget,
# Nearest to with: supplemental, cinerama, foundational, distances, maker, rewrites, geodesy, economies,
# Nearest to have: improv, surrounded, racetrack, certainly, supersymmetry, chernobyl, ascension, hangover,
# Nearest to world: hurdles, buried, seram, went, hierarchal, answer, transition, helga,
# Nearest to first: neoclassical, griswold, greatest, home, liberalisation, astatine, innumerable, gunshot,
# Nearest to from: raiders, outsource, because, clones, initial, cutting, methionine, bissette,
# Nearest to all: poses, parcels, foliage, holloway, bosom, judiciary, ed, emerging,
# Nearest to channel: clubs, conjugate, spite, clonaid, digweed, cycles, filename, ulster,
# Nearest to centre: intelligible, feline, haer, superiore, activating, showcase, cementing, else,
# Nearest to woman: arius, interregnum, evans, freeze, drinks, lazio, mob, recover,
# Nearest to experience: hole, cadence, paid, homyel, adopting, believing, produce, units,
# Nearest to resources: lovell, stanford, cz, clues, secured, lpga, layperson, sennett,
# Nearest to http: contained, luxembourgian, taliban, reginald, holger, dosing, putin, evicted,
# Nearest to bbc: and, spying, functionality, virtues, observance, eta, immediate, vili,
# Nearest to creation: discount, regrowth, chipsets, civil, assign, omitting, standardise, philosophies,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6702 0.3984 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6771 0.4055 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6240 0.4032 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6239 0.3968 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6291 0.4067 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6346 0.3937 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6024 0.2792 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5423 0.3967 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5317 0.4137 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4943 0.4058 sec/batch
# Nearest to so: exceedingly, globalisation, hallucinatory, hostilities, tinted, morrigan, makin, rebus,
# Nearest to many: its, goggles, resonate, fusible, coefficient, gadget, ventspils, regrets,
# Nearest to with: cinerama, supplemental, distances, rewrites, examinations, foundational, maker, ems,
# Nearest to have: improv, chernobyl, racetrack, supersymmetry, future, adept, hangover, certainly,
# Nearest to world: hurdles, seram, buried, went, hierarchal, slum, hydrology, helga,
# Nearest to first: neoclassical, griswold, home, liberalisation, greatest, astatine, misinterpretations, commemoration,
# Nearest to from: raiders, initial, sitcom, outsource, clones, doorstep, bissette, hillsborough,
# Nearest to all: poses, parcels, foliage, bosom, ayres, gendai, rewrite, oceanic,
# Nearest to channel: clubs, conjugate, clonaid, spite, digweed, shedd, cycles, manica,
# Nearest to centre: superiore, cementing, feline, intelligible, appeasement, kinetics, activating, showcase,
# Nearest to woman: arius, interregnum, evans, hsv, mob, freeze, lazio, mandolins,
# Nearest to experience: hole, cadence, homyel, paid, steroids, believing, adopting, studied,
# Nearest to resources: lovell, sennett, stanford, dari, cz, cody, lpga, clues,
# Nearest to http: luxembourgian, reginald, holger, taliban, contained, dosing, anhalt, peerless,
# Nearest to bbc: spying, and, partying, functionality, expressways, virtues, vili, lymphoma,
# Nearest to creation: discount, chipsets, regrowth, freespire, civil, standardise, omitting, monty,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4919 0.4101 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4973 0.4013 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4985 0.4511 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5084 0.4404 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5064 0.3954 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4642 0.3965 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4911 0.4023 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4262 0.4139 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4327 0.3976 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4411 0.3937 sec/batch
# Nearest to so: exceedingly, hallucinatory, globalisation, categorizing, before, hostilities, morrigan, eider,
# Nearest to many: its, resonate, coefficient, fusible, goggles, regrets, hapsburg, teach,
# Nearest to with: distances, cinerama, ems, rewrites, foundational, examinations, supplemental, maker,
# Nearest to have: improv, hangover, racetrack, supersymmetry, chernobyl, future, surrounded, adept,
# Nearest to world: hurdles, seram, went, hierarchal, hydrology, slum, kur, buried,
# Nearest to first: neoclassical, griswold, home, greatest, pershing, astatine, liberalisation, mahmud,
# Nearest to from: outsource, initial, raiders, hillsborough, bissette, because, clones, reissues,
# Nearest to all: poses, parcels, gendai, bosom, suitable, oceanic, add, cocos,
# Nearest to channel: clubs, conjugate, clonaid, spite, coliseum, popcorn, digweed, calderon,
# Nearest to centre: superiore, cementing, feline, appeasement, intelligible, kinetics, catechumens, fulani,
# Nearest to woman: arius, evans, hsv, mob, interregnum, lazio, cameo, mandolins,
# Nearest to experience: hole, cadence, homyel, steroids, believing, paid, studied, adopting,
# Nearest to resources: lovell, sennett, cody, dari, stanford, clues, cz, onlookers,
# Nearest to http: luxembourgian, holger, reginald, taliban, forum, contained, squaw, dosing,
# Nearest to bbc: spying, partying, clube, functionality, and, antigua, vili, eta,
# Nearest to creation: chipsets, discount, regrowth, philosophies, standardise, freespire, civil, monarchists,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4428 0.4020 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4434 0.3952 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4373 0.3993 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3896 0.3979 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3826 0.3983 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4385 0.3998 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3895 0.3981 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3857 0.4149 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4398 0.3958 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3872 0.3951 sec/batch
# Nearest to so: exceedingly, hallucinatory, morrigan, globalisation, categorizing, before, scene, rebus,
# Nearest to many: its, fusible, goggles, resonate, coefficient, teach, downed, gadget,
# Nearest to with: distances, cinerama, maker, rewrites, foundational, supplemental, includes, digs,
# Nearest to have: improv, chernobyl, future, hangover, adept, racetrack, supersymmetry, surrounded,
# Nearest to world: hurdles, seram, kur, slum, hierarchal, went, hydrology, macintoshes,
# Nearest to first: griswold, home, neoclassical, greatest, liberalisation, pershing, rooks, astatine,
# Nearest to from: hillsborough, outsource, initial, raiders, bissette, methionine, pulmonary, vitriolic,
# Nearest to all: poses, gendai, bosom, parcels, suitable, add, emerging, predicting,
# Nearest to channel: clubs, conjugate, clonaid, popcorn, fetched, rods, spite, shedd,
# Nearest to centre: superiore, feline, cementing, intelligible, kinetics, appeasement, centimeters, catechumens,
# Nearest to woman: arius, evans, mob, lazio, hsv, cameo, interregnum, mandolins,
# Nearest to experience: cadence, hole, homyel, believing, steroids, studied, adopting, conscious,
# Nearest to resources: lovell, sennett, dari, clues, cz, painfully, cody, layperson,
# Nearest to http: holger, luxembourgian, forum, html, reginald, contained, bartleby, index,
# Nearest to bbc: spying, and, clube, partying, news, functionality, grantley, eta,
# Nearest to creation: chipsets, standardise, philosophies, discount, freespire, monarchists, regrowth, civil,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3596 0.4042 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3833 0.3955 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3487 0.4098 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3718 0.4012 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3948 0.4347 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3761 0.4133 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4018 0.4129 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3687 0.3979 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3138 0.3996 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3249 0.4112 sec/batch
# Nearest to so: exceedingly, hallucinatory, categorizing, globalisation, rebus, morrigan, scene, eider,
# Nearest to many: its, resonate, fusible, goggles, teach, interpretations, coefficient, americans,
# Nearest to with: distances, cinerama, ems, rewrites, maker, foundational, hinder, supplemental,
# Nearest to have: hangover, adept, racetrack, future, improv, chernobyl, more, distinctively,
# Nearest to world: hurdles, seram, kur, hydrology, went, slum, macintoshes, transition,
# Nearest to first: griswold, neoclassical, home, misinterpretations, greatest, liberalisation, russa, rooks,
# Nearest to from: hillsborough, outsource, initial, circulation, processed, vitriolic, operand, silja,
# Nearest to all: poses, gendai, bosom, suitable, parcels, add, oceanic, ama,
# Nearest to channel: clubs, conjugate, popcorn, filename, rods, ursine, cdma, fetched,
# Nearest to centre: superiore, cementing, feline, australia, centimeters, fulani, polypropylene, kinetics,
# Nearest to woman: arius, lazio, mob, evans, relativist, hsv, cameo, stopped,
# Nearest to experience: cadence, hole, homyel, believing, steroids, conscious, paid, studied,
# Nearest to resources: lovell, sennett, cody, layperson, payment, clues, painfully, lpga,
# Nearest to http: html, htm, forum, www, holger, luxembourgian, org, index,
# Nearest to bbc: spying, news, clube, and, partying, programme, functionality, kacl,
# Nearest to creation: chipsets, philosophies, discount, standardise, monarchists, nahi, freespire, civil,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3595 0.4504 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2975 0.4637 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3768 0.4508 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3977 0.3885 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3885 0.3871 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3204 0.3979 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3210 0.3848 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3287 0.3866 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2092 0.3880 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3327 0.4007 sec/batch
# Nearest to so: rebus, exceedingly, globalisation, before, categorizing, hallucinatory, scene, morrigan,
# Nearest to many: its, fusible, resonate, teach, goggles, coefficient, cultures, americans,
# Nearest to with: distances, ems, rewrites, cinerama, maker, foundational, oi, hinder,
# Nearest to have: adept, improv, hangover, chernobyl, future, more, between, racetrack,
# Nearest to world: hurdles, kur, seram, hydrology, macintoshes, slum, vega, went,
# Nearest to first: home, griswold, misinterpretations, neoclassical, greatest, pershing, liberalisation, diamagnetic,
# Nearest to from: hillsborough, vitriolic, outsource, firefighting, kalarippayattu, pfa, circulation, pulmonary,
# Nearest to all: poses, bosom, suitable, gendai, parcels, add, predicting, oceanic,
# Nearest to channel: clubs, popcorn, fetched, ursine, cdma, rods, filename, conjugate,
# Nearest to centre: superiore, suburban, centimeters, feline, cementing, kinetics, intelligible, polypropylene,
# Nearest to woman: relativist, mob, arius, mandolins, evans, stopped, hsv, cameo,
# Nearest to experience: cadence, hole, homyel, believing, steroids, quarrel, paid, adopting,
# Nearest to resources: lovell, applets, payment, cody, constituted, clues, channels, layperson,
# Nearest to http: html, htm, www, forum, org, geocities, holger, luxembourgian,
# Nearest to bbc: spying, and, news, clube, kacl, expressways, programme, hour,
# Nearest to creation: chipsets, philosophies, monarchists, discount, standardise, nahi, freespire, bonham,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3044 0.3927 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2894 0.3882 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3337 0.1564 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2634 0.3905 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2284 0.3755 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2103 0.4509 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2389 0.3746 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2235 0.3882 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2328 0.4078 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1616 0.4816 sec/batch
# Nearest to so: exceedingly, rebus, before, globalisation, mitnagdim, eider, categorizing, scene,
# Nearest to many: resonate, its, fusible, goggles, americans, follett, mennonites, coefficient,
# Nearest to with: distances, ems, maker, rewrites, cinerama, fulcrum, the, supplemental,
# Nearest to have: hangover, adept, chernobyl, improv, future, more, between, ore,
# Nearest to world: hurdles, kur, seram, hydrology, macintoshes, slum, vega, transition,
# Nearest to first: home, greatest, griswold, misinterpretations, pershing, beefheart, rooks, mahmud,
# Nearest to from: hillsborough, vitriolic, firefighting, outsource, reissues, circulation, silja, kalarippayattu,
# Nearest to all: bosom, poses, suitable, parcels, tombs, ama, gendai, oceanic,
# Nearest to channel: clubs, popcorn, fetched, shedd, cdma, manica, ursine, clonaid,
# Nearest to centre: superiore, suburban, polypropylene, feline, boreal, bishoprics, dissection, cementing,
# Nearest to woman: relativist, mob, arius, mandolins, hsv, stopped, cameo, tellings,
# Nearest to experience: cadence, hole, homyel, believing, steroids, studied, adopting, senses,
# Nearest to resources: lovell, applets, layperson, constituted, lpga, goguryeo, ashkenazim, payment,
# Nearest to http: html, www, htm, forum, org, geocities, index, edu,
# Nearest to bbc: news, spying, clube, and, kacl, programme, grantley, expressways,
# Nearest to creation: philosophies, chipsets, monarchists, nahi, standardise, discount, freespire, regrowth,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2720 0.4510 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2245 0.4000 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2343 0.3961 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1201 0.4189 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1376 0.4227 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2015 0.4242 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1701 0.4102 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1898 0.4444 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2067 0.4212 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1781 0.4407 sec/batch
# Nearest to so: exceedingly, before, rebus, mitnagdim, eider, categorizing, globalisation, hydrates,
# Nearest to many: its, resonate, fusible, goggles, interpretations, hapsburg, americans, cultures,
# Nearest to with: ems, maker, distances, cinerama, rewrites, the, braithwaite, supplemental,
# Nearest to have: hangover, chernobyl, more, improv, adept, between, future, distinctively,
# Nearest to world: kur, hurdles, seram, macintoshes, hydrology, transition, slum, pointless,
# Nearest to first: home, greatest, griswold, pershing, misinterpretations, diamagnetic, beefheart, russa,
# Nearest to from: hillsborough, vitriolic, outsource, minerals, firefighting, processed, methionine, nucleic,
# Nearest to all: poses, suitable, bosom, add, gendai, parcels, oceanic, ama,
# Nearest to channel: clubs, cdma, fetched, shedd, popcorn, manica, digweed, ursine,
# Nearest to centre: superiore, polypropylene, suburban, boreal, bishoprics, mall, cementing, feline,
# Nearest to woman: relativist, cameo, stopped, arius, tellings, mandolins, mob, hsv,
# Nearest to experience: cadence, hole, believing, homyel, steroids, paid, conscious, senses,
# Nearest to resources: lovell, constituted, lpga, layperson, ashkenazim, goguryeo, applets, channels,
# Nearest to http: html, htm, www, forum, geocities, org, edu, index,
# Nearest to bbc: news, programme, spying, clube, grantley, and, kacl, hour,
# Nearest to creation: philosophies, chipsets, monarchists, standardise, nahi, glycosides, freespire, among,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1610 0.4825 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2221 0.4405 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1678 0.4265 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1783 0.3885 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1756 0.3879 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2109 0.3851 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2054 0.3785 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1655 0.4013 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1329 0.3867 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1769 0.3880 sec/batch
# Nearest to so: exceedingly, before, rebus, intentionally, mitnagdim, hallucinatory, eider, scene,
# Nearest to many: fusible, its, resonate, goggles, americans, cultures, interpretations, klaipeda,
# Nearest to with: maker, ems, and, rewrites, distances, the, cinerama, interfacing,
# Nearest to have: more, between, improv, chernobyl, hangover, adept, distinctively, depends,
# Nearest to world: kur, macintoshes, hurdles, seram, transition, fifa, slum, hydrology,
# Nearest to first: griswold, home, greatest, rooks, misinterpretations, beefheart, pershing, russa,
# Nearest to from: vitriolic, hillsborough, silja, raffles, outsource, firefighting, methionine, kalarippayattu,
# Nearest to all: bosom, suitable, poses, gendai, hath, predicting, add, oceanic,
# Nearest to channel: clubs, cdma, fetched, popcorn, shedd, manica, digweed, clonaid,
# Nearest to centre: superiore, polypropylene, suburban, boreal, mall, cementing, bishoprics, dissection,
# Nearest to woman: cameo, stopped, relativist, sex, mandolins, tellings, evans, arius,
# Nearest to experience: cadence, hole, believing, homyel, conscious, steroids, virtues, gibberish,
# Nearest to resources: lovell, layperson, lpga, channels, ashkenazim, applets, goguryeo, cz,
# Nearest to http: html, www, htm, forum, geocities, org, index, edu,
# Nearest to bbc: news, programme, spying, clube, kacl, links, and, grantley,
# Nearest to creation: philosophies, standardise, monarchists, chipsets, nahi, glycosides, freespire, explain,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1738 0.3903 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1489 0.3616 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1833 0.3676 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2098 0.4270 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1531 0.4538 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1351 0.4124 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1454 0.4123 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1262 0.3785 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1762 0.3968 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2221 0.4202 sec/batch
# Nearest to so: exceedingly, rebus, before, eider, prosecutions, intentionally, mitnagdim, hostilities,
# Nearest to many: fusible, americans, resonate, its, regrets, cultures, interpretations, teach,
# Nearest to with: rewrites, ems, maker, cinerama, and, the, methodism, fulcrum,
# Nearest to have: more, hangover, improv, between, chernobyl, adept, future, ore,
# Nearest to world: kur, hurdles, fifa, macintoshes, transition, hydrology, vega, slum,
# Nearest to first: home, griswold, greatest, misinterpretations, rooks, pershing, beefheart, heroics,
# Nearest to from: hillsborough, silja, vitriolic, raffles, kilkenny, outsource, firefighting, reissues,
# Nearest to all: bosom, suitable, gendai, hath, poses, tombs, oceanic, predicting,
# Nearest to channel: clubs, cdma, fetched, digweed, shedd, manica, sgi, popcorn,
# Nearest to centre: superiore, polypropylene, suburban, bishoprics, boreal, cementing, mall, konkani,
# Nearest to woman: sex, relativist, tellings, cameo, mandolins, recover, stopped, amok,
# Nearest to experience: cadence, hole, believing, homyel, paid, steroids, gibberish, jann,
# Nearest to resources: lovell, goguryeo, layperson, lpga, ashkenazim, rspca, channels, deltas,
# Nearest to http: html, www, htm, geocities, forum, org, edu, index,
# Nearest to bbc: news, spying, programme, links, clube, baqir, kacl, discuss,
# Nearest to creation: philosophies, standardise, monarchists, pubns, polytheistic, glycosides, sinope, chipsets,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2259 0.4492 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1601 0.4954 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1216 0.4694 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1354 0.4271 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0673 0.4382 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1572 0.4368 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1389 0.4453 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1315 0.4211 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1802 0.0373 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1234 0.4145 sec/batch
# Nearest to so: before, exceedingly, rebus, mitnagdim, eider, hostilities, prosecutions, globalisation,
# Nearest to many: fusible, resonate, its, americans, goggles, linking, cultures, regrets,
# Nearest to with: and, the, rewrites, ems, maker, nonliving, entirety, fulcrum,
# Nearest to have: more, hangover, between, chernobyl, adept, ore, improv, depends,
# Nearest to world: kur, macintoshes, transition, fifa, hurdles, slum, hydrology, vega,
# Nearest to first: home, greatest, griswold, misinterpretations, diamagnetic, beefheart, russa, mahmud,
# Nearest to from: vitriolic, firefighting, hillsborough, reissues, outsource, raffles, silja, tapioca,
# Nearest to all: suitable, bosom, gendai, poses, add, oceanic, parcels, ama,
# Nearest to channel: clubs, cdma, fetched, shedd, digweed, sgi, updated, manica,
# Nearest to centre: superiore, suburban, mall, polypropylene, boreal, konkani, bishoprics, laval,
# Nearest to woman: sex, relativist, tellings, recover, mandolins, immolation, hsv, haddon,
# Nearest to experience: cadence, hole, glossy, steroids, senses, believing, homyel, paid,
# Nearest to resources: lovell, goguryeo, rspca, lpga, channels, ashkenazim, deltas, layperson,
# Nearest to http: html, www, htm, geocities, forum, edu, index, org,
# Nearest to bbc: news, spying, clube, programme, links, baqir, kacl, discuss,
# Nearest to creation: philosophies, standardise, monarchists, glycosides, chipsets, polytheistic, nahi, pubns,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1062 0.3632 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0334 0.3304 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1081 0.3281 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0420 0.3292 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0484 0.3291 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0371 0.3349 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0985 0.3282 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1411 0.3299 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1114 0.3296 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0437 0.3427 sec/batch
# Nearest to so: before, exceedingly, rebus, hostilities, give, mitnagdim, intentionally, prosecutions,
# Nearest to many: resonate, its, fusible, americans, linking, comprising, anchovies, cultures,
# Nearest to with: and, the, ems, slow, fulcrum, rewrites, distances, entirety,
# Nearest to have: hangover, chernobyl, more, between, ore, improv, adept, distinctively,
# Nearest to world: fifa, kur, hurdles, vega, slum, transition, hydrology, macintoshes,
# Nearest to first: home, greatest, misinterpretations, griswold, rooks, beefheart, mahmud, pershing,
# Nearest to from: hillsborough, firefighting, vitriolic, sikhism, reissues, minerals, outsource, methionine,
# Nearest to all: suitable, bosom, poses, imparts, gendai, oceanic, add, parcels,
# Nearest to channel: clubs, cdma, fetched, digweed, shedd, bbc, sgi, manica,
# Nearest to centre: superiore, polypropylene, suburban, mall, boreal, konkani, bishoprics, dissection,
# Nearest to woman: relativist, sex, tellings, stopped, mandolins, recover, haddon, hsv,
# Nearest to experience: cadence, hole, believing, glossy, senses, gibberish, paying, steroids,
# Nearest to resources: rspca, goguryeo, channels, ashkenazim, deltas, lovell, constituted, natural,
# Nearest to http: www, html, htm, geocities, forum, edu, org, index,
# Nearest to bbc: news, programme, spying, clube, links, hour, channel, kacl,
# Nearest to creation: philosophies, standardise, glycosides, monarchists, sinope, cosmological, polytheistic, pubns,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0099 0.4326 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0227 0.3842 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9941 0.3979 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0684 0.4272 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0733 0.3797 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0628 0.3993 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0658 0.3887 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1236 0.3864 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0899 0.3867 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0389 0.3869 sec/batch
# Nearest to so: before, exceedingly, rebus, give, mitnagdim, hydrates, hostilities, fades,
# Nearest to many: resonate, americans, fusible, its, interpretations, goggles, increasingly, letterbox,
# Nearest to with: and, the, interfacing, maker, methodism, thru, cinerama, ems,
# Nearest to have: hangover, chernobyl, more, between, improv, ore, distinctively, adept,
# Nearest to world: macintoshes, fifa, kur, transition, vega, hurdles, throwers, slum,
# Nearest to first: home, griswold, greatest, misinterpretations, heroics, wizards, lazy, beefheart,
# Nearest to from: methionine, minerals, gamut, outsource, intertwined, hillsborough, nucleic, vitriolic,
# Nearest to all: suitable, poses, bosom, add, oceanic, imparts, gendai, tombs,
# Nearest to channel: bbc, fetched, cdma, shedd, clubs, digweed, calderon, manica,
# Nearest to centre: superiore, suburban, polypropylene, konkani, mall, boreal, dissection, fulani,
# Nearest to woman: relativist, tellings, sex, stopped, mandolins, haddon, recover, hsv,
# Nearest to experience: cadence, hole, senses, studied, glossy, conscious, virtues, paying,
# Nearest to resources: deltas, channels, goguryeo, dsp, natural, ashkenazim, lovell, rspca,
# Nearest to http: html, www, htm, geocities, edu, org, forum, index,
# Nearest to bbc: news, programme, spying, clube, channel, links, hour, kacl,
# Nearest to creation: philosophies, standardise, cosmological, monarchists, pubns, sinope, explain, gmail,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0636 0.3919 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0753 0.3861 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0684 0.3858 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0549 0.4590 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0908 0.3916 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0529 0.3910 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0414 0.3845 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0758 0.3854 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1035 0.4000 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0645 0.3886 sec/batch
# Nearest to so: before, rebus, exceedingly, hostilities, prosecutions, give, mitnagdim, scene,
# Nearest to many: americans, fusible, its, resonate, regrets, shaw, interpretations, guth,
# Nearest to with: and, the, brutal, ems, methodism, cluetrain, maker, entirety,
# Nearest to have: between, chernobyl, more, improv, future, hangover, distinctively, locative,
# Nearest to world: fifa, kur, macintoshes, hurdles, vega, transition, slum, throwers,
# Nearest to first: griswold, misinterpretations, home, greatest, etchings, lazy, beefheart, diamagnetic,
# Nearest to from: the, tapioca, hillsborough, silja, vitriolic, raffles, circulation, acacias,
# Nearest to all: suitable, bosom, gendai, add, imparts, poses, hath, tombs,
# Nearest to channel: fetched, bbc, cdma, shedd, calderon, digweed, pstn, clubs,
# Nearest to centre: superiore, polypropylene, suburban, konkani, mall, boreal, bishoprics, dissection,
# Nearest to woman: relativist, tellings, mandolins, sex, recover, haddon, stopped, urquhart,
# Nearest to experience: cadence, paying, hole, conscious, senses, centrality, virtues, jann,
# Nearest to resources: mime, lpga, goguryeo, layperson, oddities, deltas, lovell, dsp,
# Nearest to http: html, htm, www, geocities, forum, edu, index, org,
# Nearest to bbc: news, programme, spying, clube, channel, hour, links, discuss,
# Nearest to creation: standardise, philosophies, sinope, pubns, cosmological, monarchists, gmail, slovenians,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0643 0.3978 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9995 0.3870 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0303 0.3869 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0972 0.3886 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0628 0.3895 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1431 0.3878 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1247 0.3858 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0538 0.3889 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0618 0.3866 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0353 0.3846 sec/batch
# Nearest to so: before, rebus, exceedingly, give, prosecutions, hostilities, mitnagdim, spaniard,
# Nearest to many: americans, its, fusible, resonate, regrets, shaw, letterbox, verant,
# Nearest to with: and, the, country, methodism, interfacing, thru, foundational, isidor,
# Nearest to have: more, between, chernobyl, hangover, locative, taxonomic, improv, depends,
# Nearest to world: fifa, kur, vega, transition, slum, macintoshes, hurdles, prefered,
# Nearest to first: griswold, misinterpretations, home, greatest, mahmud, beefheart, astatine, diamagnetic,
# Nearest to from: silja, tapioca, hillsborough, mnemosyne, gamut, intertwined, methionine, vitriolic,
# Nearest to all: suitable, add, imparts, bosom, gendai, poses, oceanic, specified,
# Nearest to channel: fetched, pstn, cdma, bbc, shedd, digweed, updated, calderon,
# Nearest to centre: superiore, polypropylene, suburban, konkani, bishoprics, mall, laval, boreal,
# Nearest to woman: relativist, sex, tellings, haddon, mandolins, stopped, recover, pregnancies,
# Nearest to experience: cadence, senses, jann, hole, studied, conscious, centrality, paying,
# Nearest to resources: lpga, goguryeo, mime, deltas, channels, natural, dsp, rspca,
# Nearest to http: htm, html, www, geocities, edu, org, forum, index,
# Nearest to bbc: news, programme, spying, clube, links, baqir, channel, hour,
# Nearest to creation: philosophies, standardise, pubns, sinope, slovenians, monarchists, cosmological, gmail,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0069 0.3912 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0029 0.3965 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0257 0.4480 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9946 0.4164 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0614 0.3919 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0183 0.3602 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0212 0.4017 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9970 0.3370 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0005 0.3346 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9517 0.3351 sec/batch
# Nearest to so: before, rebus, exceedingly, give, prosecutions, hostilities, mitnagdim, prophesy,
# Nearest to many: regrets, americans, its, fusible, resonate, zoroastrianism, interpretations, letterbox,
# Nearest to with: and, the, thru, ems, country, methodism, isidor, clinch,
# Nearest to have: more, hangover, chernobyl, ore, locative, stereotyping, adept, improv,
# Nearest to world: fifa, macintoshes, vega, kur, throwers, slum, transition, hurdles,
# Nearest to first: misinterpretations, launched, beefheart, mahmud, greatest, home, wizards, heroics,
# Nearest to from: gamut, mnemosyne, silja, methionine, mascot, intertwined, hillsborough, reissues,
# Nearest to all: suitable, bosom, add, imparts, hath, gendai, poses, oceanic,
# Nearest to channel: bbc, fetched, pstn, cdma, shedd, digweed, vulcan, calderon,
# Nearest to centre: superiore, konkani, polypropylene, suburban, mall, dissection, boreal, laval,
# Nearest to woman: relativist, sex, tellings, pregnancies, stopped, haddon, infant, urquhart,
# Nearest to experience: cadence, senses, centrality, studied, conscious, hole, jann, paying,
# Nearest to resources: goguryeo, rspca, natural, lpga, oddities, mime, cnica, dsp,
# Nearest to http: htm, www, html, geocities, edu, forum, org, index,
# Nearest to bbc: news, programme, spying, links, channel, baqir, hour, ponce,
# Nearest to creation: philosophies, standardise, sinope, cosmological, pubns, slovenians, denser, gmail,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0051 0.3420 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9215 0.3351 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0145 0.3349 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0157 0.3372 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0339 0.3394 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0017 21.8326 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9245 32.3680 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9541 21.4013 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9496 0.3971 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9448 13.0319 sec/batch
# Nearest to so: rebus, before, exceedingly, give, prosecutions, hostilities, hydrates, fades,
# Nearest to many: fusible, resonate, its, americans, regrets, zoroastrianism, comprising, a,
# Nearest to with: and, the, country, ems, thru, methodism, isidor, totals,
# Nearest to have: more, chernobyl, ore, hangover, between, stereotyping, dobruja, gaas,
# Nearest to world: fifa, macintoshes, vega, transition, kur, throwers, hurdles, personnel,
# Nearest to first: wizards, beefheart, greatest, home, misinterpretations, firings, astatine, diamagnetic,
# Nearest to from: tapioca, gamut, mnemosyne, intertwined, methionine, minerals, outsource, acacias,
# Nearest to all: suitable, add, bosom, imparts, gendai, poses, hath, if,
# Nearest to channel: bbc, fetched, cdma, broadcasts, shedd, calderon, pstn, digweed,
# Nearest to centre: superiore, polypropylene, konkani, suburban, boreal, dissection, mall, laval,
# Nearest to woman: sex, relativist, tellings, haddon, pregnancies, stopped, infant, urquhart,
# Nearest to experience: cadence, senses, studied, hole, centrality, conscious, glossy, vocational,
# Nearest to resources: rspca, natural, goguryeo, deltas, dsp, oddities, mime, ashkenazim,
# Nearest to http: htm, html, www, geocities, edu, forum, org, site,
# Nearest to bbc: news, programme, channel, spying, links, hour, baqir, warmth,
# Nearest to creation: standardise, philosophies, pubns, cosmological, slovenians, gmail, denser, hinder,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9865 32.3678 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0252 32.3622 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9637 26.3417 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9976 32.3776 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0487 19.1076 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9558 43.4964 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9831 0.4109 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0097 0.3849 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9566 0.3958 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9876 0.3879 sec/batch
# Nearest to so: rebus, exceedingly, before, give, prosecutions, hallucinatory, truly, prophesy,
# Nearest to many: americans, its, regrets, fusible, interpretations, resonate, pals, verant,
# Nearest to with: and, the, methodism, country, thru, a, isidor, introducing,
# Nearest to have: more, between, chernobyl, ore, taxonomic, improv, stadia, locative,
# Nearest to world: fifa, macintoshes, vega, throwers, prefered, transition, hurdles, personnel,
# Nearest to first: in, greatest, beefheart, astatine, misinterpretations, griswold, launched, wizards,
# Nearest to from: etc, gamut, tapioca, intertwined, methionine, hillsborough, nomen, silja,
# Nearest to all: suitable, add, gendai, hath, bosom, are, imparts, if,
# Nearest to channel: bbc, cdma, broadcasts, fetched, shedd, brendan, calderon, pstn,
# Nearest to centre: superiore, polypropylene, konkani, dissection, laval, boreal, bishoprics, suburban,
# Nearest to woman: relativist, sex, tellings, haddon, stopped, infant, pregnancies, urquhart,
# Nearest to experience: cadence, studied, senses, conscious, affliction, centrality, hole, fundamentals,
# Nearest to resources: natural, dsp, deltas, oddities, rspca, goguryeo, mime, ashkenazim,
# Nearest to http: html, www, htm, geocities, edu, org, forum, index,
# Nearest to bbc: news, programme, channel, spying, links, hour, baqir, clube,
# Nearest to creation: standardise, pubns, philosophies, cosmological, gmail, sinope, denser, slovenians,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0116 0.3951 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0000 0.3908 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9671 0.3981 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0141 0.3896 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9887 0.3904 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9995 0.3468 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9750 0.3401 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9720 0.3414 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9688 0.3372 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9918 0.3411 sec/batch
# Nearest to so: rebus, exceedingly, before, prosecutions, give, hostilities, truly, hydrates,
# Nearest to many: americans, regrets, fusible, resonate, its, zoroastrianism, verant, shaw,
# Nearest to with: and, the, methodism, country, a, entirety, fraught, thru,
# Nearest to have: more, locative, chernobyl, between, taxonomic, ore, stereotyping, gaas,
# Nearest to world: fifa, macintoshes, vega, prefered, throwers, transition, fund, hurdles,
# Nearest to first: misinterpretations, greatest, in, griswold, beefheart, astatine, etchings, launched,
# Nearest to from: the, intertwined, outsource, etc, with, gamut, tapioca, nomen,
# Nearest to all: suitable, gendai, are, imparts, pares, add, hath, if,
# Nearest to channel: bbc, cdma, fetched, pstn, broadcasts, shedd, broadcasting, channels,
# Nearest to centre: superiore, polypropylene, konkani, dissection, bishoprics, laval, boreal, telecommunications,
# Nearest to woman: relativist, sex, tellings, haddon, pregnancies, infant, urquhart, fertility,
# Nearest to experience: cadence, senses, studied, centrality, affliction, conscious, roswell, hole,
# Nearest to resources: natural, goguryeo, rspca, oddities, deltas, ashkenazim, dsp, lpga,
# Nearest to http: htm, html, www, geocities, edu, org, forum, index,
# Nearest to bbc: news, programme, spying, channel, links, baqir, clube, discuss,
# Nearest to creation: standardise, pubns, hinder, philosophies, gmail, sinope, cosmological, slovenians,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9572 0.3558 sec/batch
# ...
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8056 0.3863 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7898 0.3847 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7814 0.3874 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8422 0.3861 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8633 0.3870 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8043 0.3870 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8102 58.3751 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9466 15.4399 sec/batch
# Nearest to so: give, beneficial, that, was, it, prosecutions, everyone, clear,
# Nearest to many: some, most, for, with, not, resonate, of, consider,
# Nearest to with: and, the, a, from, an, to, in, sharing,
# Nearest to have: more, a, to, survived, this, even, reds, defective,
# Nearest to world: fifa, macintoshes, reefs, vega, hosts, entebbe, ktav, sundials,
# Nearest to first: in, was, before, the, greatest, on, early, launched,
# Nearest to from: with, the, and, a, gifford, turn, also, in,
# Nearest to all: are, those, and, is, their, them, suitable, as,
# Nearest to channel: aired, fox, cdma, bbc, loss, broadcasts, fidelity, calderon,
# Nearest to centre: polypropylene, motorsport, laval, relativistic, superiore, plenum, konkani, boreal,
# Nearest to woman: sex, pregnancies, relativist, infant, arrogant, women, haddon, mestizo,
# Nearest to experience: cadence, roswell, investing, conscious, gamer, praia, jann, senses,
# Nearest to resources: goguryeo, rspca, deltas, layperson, dsp, timber, applets, oddities,
# Nearest to http: www, htm, html, geocities, edu, luxembourgian, forum, index,
# Nearest to bbc: programme, news, links, spying, channel, fcc, discuss, feininger,
# Nearest to creation: cosmological, denser, standardise, bonham, gmail, pubns, eared, ultimate,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8635 0.4099 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8172 0.4017 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8592 0.3855 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8460 0.3796 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8568 0.3716 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8784 0.3625 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8374 0.3510 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8402 0.3502 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8719 0.3802 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8523 0.3911 sec/batch
# Nearest to so: give, that, beneficial, was, clear, it, prosecutions, everyone,
# Nearest to many: some, most, for, with, not, were, resonate, of,
# Nearest to with: and, a, the, from, to, in, an, country,
# Nearest to have: a, to, even, this, survived, more, that, but,
# Nearest to world: fifa, reefs, macintoshes, ktav, vega, hosts, taunus, entebbe,
# Nearest to first: in, was, before, the, early, greatest, launched, later,
# Nearest to from: the, with, and, a, in, also, gifford, turn,
# Nearest to all: are, and, those, pares, is, the, as, their,
# Nearest to channel: aired, fox, broadcasts, bbc, cdma, loss, fidelity, calderon,
# Nearest to centre: polypropylene, motorsport, laval, bishoprics, konkani, boreal, plenum, superiore,
# Nearest to woman: sex, relativist, pregnancies, infant, arrogant, mestizo, women, haddon,
# Nearest to experience: cadence, roswell, investing, conscious, praia, jann, gamer, paying,
# Nearest to resources: goguryeo, rspca, deltas, timber, layperson, natural, resource, dsp,
# Nearest to http: www, htm, html, geocities, edu, index, luxembourgian, forum,
# Nearest to bbc: programme, news, links, spying, discuss, february, fcc, channel,
# Nearest to creation: cosmological, denser, standardise, gmail, pubns, ultimate, sinope, bonham,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8332 0.4313 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8509 0.4214 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8262 0.3421 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8361 0.3655 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8755 0.4101 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8372 0.3958 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9448 0.3914 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9236 0.3903 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8832 0.3753 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8399 0.3695 sec/batch
# Nearest to so: give, that, clear, was, beneficial, rebus, everyone, prosecutions,
# Nearest to many: some, most, verant, estimated, with, for, consider, resonate,
# Nearest to with: and, the, a, from, an, to, country, in,
# Nearest to have: survived, a, even, to, that, more, some, are,
# Nearest to world: fifa, macintoshes, reefs, ktav, fund, entebbe, horowitz, farben,
# Nearest to first: in, was, before, the, launched, greatest, early, later,
# Nearest to from: the, with, and, turn, a, in, also, s,
# Nearest to all: are, those, and, their, pares, is, they, as,
# Nearest to channel: aired, fox, broadcasts, cdma, fidelity, loss, broadcasting, bbc,
# Nearest to centre: polypropylene, bishoprics, motorsport, konkani, laval, boreal, superiore, plenum,
# Nearest to woman: sex, pregnancies, relativist, infant, arrogant, women, haddon, mestizo,
# Nearest to experience: roswell, cadence, praia, gamer, conscious, jann, investing, senses,
# Nearest to resources: goguryeo, rspca, timber, deltas, layperson, natural, nurtured, applets,
# Nearest to http: www, htm, html, geocities, edu, luxembourgian, index, forum,
# Nearest to bbc: programme, news, links, february, spying, discuss, remaining, listing,
# Nearest to creation: bonham, cosmological, pubns, denser, sinope, standardise, smilga, gmail,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8070 0.4070 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8766 0.4852 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7458 0.4799 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8649 0.4502 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8500 0.4386 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8343 0.5183 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8908 0.1228 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8294 0.3837 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8369 0.6650 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8185 0.7865 sec/batch
# Nearest to so: give, that, clear, was, beneficial, prosecutions, ossetia, hydrates,
# Nearest to many: some, resonate, estimated, consider, most, with, onychophora, chromic,
# Nearest to with: and, a, the, from, an, to, in, country,
# Nearest to have: a, survived, even, some, to, that, more, there,
# Nearest to world: fifa, ktav, macintoshes, entebbe, reefs, farben, war, ribbentrop,
# Nearest to first: in, was, before, the, later, early, on, during,
# Nearest to from: the, with, and, also, in, a, turn, this,
# Nearest to all: are, those, their, and, pares, they, non, them,
# Nearest to channel: aired, broadcasts, fox, fidelity, cdma, loss, channels, broadcasting,
# Nearest to centre: polypropylene, motorsport, konkani, bishoprics, boreal, laval, willows, superiore,
# Nearest to woman: sex, pregnancies, infant, relativist, women, arrogant, mestizo, her,
# Nearest to experience: roswell, cadence, conscious, gamer, praia, investing, studied, fundamentals,
# Nearest to resources: goguryeo, rspca, deltas, timber, natural, layperson, nurtured, numismatics,
# Nearest to http: www, htm, html, geocities, edu, index, luxembourgian, org,
# Nearest to bbc: programme, news, links, february, listing, remaining, spying, fcc,
# Nearest to creation: cosmological, bonham, denser, standardise, pubns, smilga, slovenians, gmail,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8454 0.9134 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7784 1.0208 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8343 1.1970 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7629 1.0579 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8464 69.5989 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8427 0.3609 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8833 0.3776 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7665 0.4207 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7767 0.3637 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7655 0.3621 sec/batch
# Nearest to so: that, give, beneficial, clear, everyone, hydrates, make, truly,
# Nearest to many: some, for, most, not, a, of, consider, and,
# Nearest to with: and, a, the, from, an, to, in, their,
# Nearest to have: to, a, more, some, even, but, survived, are,
# Nearest to world: fifa, reefs, macintoshes, entebbe, ktav, ribbentrop, farben, war,
# Nearest to first: in, was, before, the, greatest, later, on, second,
# Nearest to from: the, and, with, a, also, in, turn, this,
# Nearest to all: are, is, and, those, as, which, their, of,
# Nearest to channel: aired, fox, broadcasts, loss, calderon, affiliates, fidelity, bbc,
# Nearest to centre: polypropylene, motorsport, konkani, bishoprics, boreal, laval, superiore, fulani,
# Nearest to woman: sex, pregnancies, infant, relativist, arrogant, haddon, women, mestizo,
# Nearest to experience: roswell, conscious, gamer, praia, cadence, investing, studied, fundamentals,
# Nearest to resources: goguryeo, deltas, rspca, timber, natural, layperson, resource, applets,
# Nearest to http: www, htm, html, geocities, edu, luxembourgian, org, index,
# Nearest to bbc: programme, news, links, spying, fcc, listing, february, remaining,
# Nearest to creation: standardise, denser, pubns, cosmological, bonham, passports, slovenians, smilga,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7363 0.3408 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7885 0.3375 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8266 0.3773 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8283 0.3723 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8224 0.4953 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9022 0.4375 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8285 0.4250 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8150 0.4830 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8291 0.5449 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8189 0.3554 sec/batch
# Nearest to so: give, that, clear, beneficial, everyone, hydrates, prosecutions, was,
# Nearest to many: some, of, most, only, with, not, for, and,
# Nearest to with: and, a, the, from, to, an, in, country,
# Nearest to have: to, a, that, survived, even, are, more, some,
# Nearest to world: fifa, macintoshes, reefs, ktav, entebbe, war, horowitz, united,
# Nearest to first: in, was, the, before, greatest, on, later, early,
# Nearest to from: the, with, a, and, also, this, by, in,
# Nearest to all: are, and, is, they, those, their, it, pares,
# Nearest to channel: aired, broadcasts, fox, loss, fidelity, bbc, cdma, broadcasting,
# Nearest to centre: polypropylene, motorsport, konkani, bishoprics, willows, laval, boreal, plenum,
# Nearest to woman: sex, pregnancies, infant, arrogant, relativist, her, women, haddon,
# Nearest to experience: roswell, investing, conscious, praia, gamer, studied, cadence, petrov,
# Nearest to resources: goguryeo, rspca, timber, deltas, applets, layperson, dsp, auth,
# Nearest to http: www, htm, html, geocities, edu, luxembourgian, index, org,
# Nearest to bbc: programme, news, february, remaining, listing, spying, programmes, links,
# Nearest to creation: standardise, cosmological, pubns, bonham, controversy, denser, passports, smilga,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8731 0.4682 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8199 0.3749 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8463 0.3782 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8470 0.3851 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8267 0.3878 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8289 0.3681 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8494 0.3874 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8108 0.3724 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8120 0.3749 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8054 0.3825 sec/batch
# Nearest to so: that, give, clear, beneficial, everyone, prosecutions, it, was,
# Nearest to many: some, only, most, of, however, with, in, for,
# Nearest to with: and, a, the, from, to, an, in, various,
# Nearest to have: a, to, some, even, more, are, but, this,
# Nearest to world: fifa, macintoshes, ktav, international, entebbe, reefs, hosts, iho,
# Nearest to first: in, was, the, before, early, later, greatest, as,
# Nearest to from: the, with, and, a, also, this, in, by,
# Nearest to all: are, and, is, the, those, as, of, they,
# Nearest to channel: aired, fox, fidelity, broadcasts, cdma, loss, broadcasting, channels,
# Nearest to centre: polypropylene, konkani, motorsport, bishoprics, laval, boreal, pillaging, fulani,
# Nearest to woman: sex, pregnancies, infant, relativist, arrogant, mestizo, women, feminist,
# Nearest to experience: roswell, praia, investing, gamer, cadence, conscious, petrov, goes,
# Nearest to resources: goguryeo, natural, rspca, layperson, timber, resource, mime, deltas,
# Nearest to http: www, htm, html, geocities, edu, luxembourgian, index, org,
# Nearest to bbc: programme, news, february, listing, remaining, links, spying, programmes,
# Nearest to creation: created, standardise, passports, gmail, denser, cosmological, bonham, controversy,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8288 0.3729 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8364 0.4028 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8955 0.3977 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9073 0.4806 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8629 0.3904 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8469 0.3965 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7756 0.3592 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8024 0.3412 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7249 0.3353 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8383 0.3375 sec/batch
# Nearest to so: that, give, clear, beneficial, everyone, was, it, make,
# Nearest to many: some, with, most, only, and, for, however, estimated,
# Nearest to with: and, the, a, to, from, an, in, of,
# Nearest to have: to, a, even, some, more, but, are, that,
# Nearest to world: fifa, ktav, reefs, macintoshes, entebbe, war, international, history,
# Nearest to first: was, in, before, the, early, later, launched, greatest,
# Nearest to from: the, with, and, this, a, also, s, in,
# Nearest to all: are, and, is, their, which, the, those, in,
# Nearest to channel: fox, aired, broadcasts, fidelity, broadcasting, cdma, loss, channels,
# Nearest to centre: polypropylene, konkani, motorsport, bishoprics, laval, zubr, boreal, fulani,
# Nearest to woman: sex, pregnancies, infant, relativist, arrogant, women, mestizo, feminist,
# Nearest to experience: roswell, praia, gamer, conscious, cadence, investing, petrov, goes,
# Nearest to resources: natural, rspca, timber, goguryeo, mime, resource, auth, deltas,
# Nearest to http: www, htm, html, geocities, edu, org, index, luxembourgian,
# Nearest to bbc: programme, february, news, remaining, links, listing, spying, fcc,
# Nearest to creation: smilga, dwindled, slovenians, passports, created, denser, standardise, bonham,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8369 0.3398 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8356 0.3528 sec/batch
# Epoch 10/10 Iteration: 46300 Avg. Training loss: 3.8722 0.3372 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
